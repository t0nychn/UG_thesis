# %%
from utils import *

# %%
betas = load('data/saved/betas.csv')

# %%
plt.figure(figsize=(20,5))
#betas['GSCI-SPX-smth'].plot()
betas['GSECI-SPX-smth'].plot()
betas['GSNECI-SPX-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
#betas['GSCI-MSCI_W-smth'].plot()
betas['GSECI-MSCI_W-smth'].plot()
betas['GSNECI-MSCI_W-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
#betas['GSCI-MSCI_EM-smth'].plot()
betas['GSECI-MSCI_EM-smth'].plot()
betas['GSNECI-MSCI_EM-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
#betas['GSCI-SPX-smth'].plot()
betas['GSCI-MSCI_W-smth'].plot()
betas['GSCI-MSCI_EM-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
#betas['GSECI-SPX-smth'].plot()
betas['GSECI-MSCI_W-smth'].plot()
betas['GSECI-MSCI_EM-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
#betas['GSNECI-SPX-smth'].plot()
betas['GSNECI-MSCI_W-smth'].plot()
betas['GSNECI-MSCI_EM-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
probs = load('data/saved/probs.csv')

# %%
plt.figure(figsize=(20,5))
#probs['GSCI-SPX-smth'].plot()
probs['GSECI-SPX-smth'].plot()
probs['GSNECI-SPX-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
#probs['GSCI-MSCI_W-smth'].plot()
probs['GSECI-MSCI_W-smth'].plot()
probs['GSNECI-MSCI_W-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
#probs['GSCI-MSCI_EM-smth'].plot()
probs['GSECI-MSCI_EM-smth'].plot()
probs['GSNECI-MSCI_EM-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
betas['GSECI-GSNECI-smth'].plot()
betas['GSNECI-GSECI-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()
