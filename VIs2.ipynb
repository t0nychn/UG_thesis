# %%
from utils import *

# %%
betas = load('data/saved/betas2.csv')
probs = load('data/saved/probs2.csv')

# %% [markdown]
# # Non-indexed

# %%
plt.figure(figsize=(20,5))
means = 0
for i in {'lumber', 'oats', 'palladium', 'rubber'}:
    betas[f'{i}-SPX-smth'].plot()
    means += betas[f'{i}-SPX-smth']
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(15,7/3))
plt.axhline(0, color='grey', linestyle='--')
plt.plot(means/4)

# %%
plt.figure(figsize=(20,5))
for i in {'lumber', 'oats', 'palladium', 'rubber'}:
    betas[f'{i}-MSCI_W-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
for i in {'lumber', 'oats', 'palladium', 'rubber'}:
    betas[f'{i}-MSCI_EM-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
for i in {'lumber', 'oats', 'palladium', 'rubber'}:
    betas[f'{i}-GSCI-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
for i in {'lumber', 'oats', 'palladium', 'rubber'}:
    betas[f'{i}-GSNECI-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
for i in {'lumber', 'oats', 'palladium', 'rubber'}:
    betas[f'{i}-GSECI-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %% [markdown]
# # Indexed

# %%
b1 = load('data/saved/betas.csv')

# %%
plt.figure(figsize=(20,5))
x = 'SPX'
means = 0
for i in {'gold','hog', 'wheat'}:
    betas[f'{i}-{x}-smth'].plot()
    means += betas[f'{i}-{x}-smth']
for i in {'WTI', 'gas'}:
    b1[f'{i}-{x}-smth'].plot()
    means += b1[f'{i}-{x}-smth']
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(15,7/3))
plt.axhline(0, color='grey', linestyle='--')
plt.plot(means/5)

# %%
plt.figure(figsize=(20,5))
x = 'MSCI_W'
for i in {'gold','hog', 'wheat'}:
    betas[f'{i}-{x}-smth'].plot()
for i in {'WTI', 'gas'}:
    b1[f'{i}-{x}-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
x = 'MSCI_EM'
for i in {'gold','hog', 'wheat'}:
    betas[f'{i}-{x}-smth'].plot()
for i in {'WTI', 'gas'}:
    b1[f'{i}-{x}-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()

# %%
plt.figure(figsize=(20,5))
x = 'GSCI'
for i in {'gold','hog', 'wheat'}:
    betas[f'{i}-{x}-smth'].plot()
for i in {'WTI', 'gas'}:
    b1[f'{i}-{x}-smth'].plot()
plt.axhline(0, color='grey', linestyle='--')
plt.legend()
