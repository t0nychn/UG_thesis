# %%
from estimator_simulation import *

# %%
rand_ints()
# Out:
# 0.5148017979222068

# %%
rand_ints_short()
# Out:
# 3.1898186810370763

# %%
trending_rand_ints()
# Out:
# -0.6603456723688055

# %%
var_rand_ints()
# Out:
# 122.4187634010425

# %%
anomaly_rand_ints()
# Out:
# -0.34808858842271295
