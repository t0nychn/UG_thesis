# %%
from utils import *

# %%
volume = load('data/volume.csv')
a = volume['GSCI'].rolling(12).mean()
b = volume['BCI'].rolling(12).mean()
sigma = (a+b)

# %%
betas = load('data/saved/betas-master.csv')

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
t = grangercausalitytests(betas[['GSCI-SPX-smth']].join(sigma.rename('volume').pct_change()).dropna(), maxlag=12)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8439  , p=0.3597  , df_denom=152, df_num=1
# ssr based chi2 test:   chi2=0.8606  , p=0.3536  , df=1
# likelihood ratio test: chi2=0.8582  , p=0.3542  , df=1
# parameter F test:         F=0.8439  , p=0.3597  , df_denom=152, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5568  , p=0.5742  , df_denom=149, df_num=2
# ssr based chi2 test:   chi2=1.1511  , p=0.5624  , df=2
# likelihood ratio test: chi2=1.1468  , p=0.5636  , df=2
# parameter F test:         F=0.5568  , p=0.5742  , df_denom=149, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5459  , p=0.6517  , df_denom=146, df_num=3
# ssr based chi2 test:   chi2=1.7163  , p=0.6333  , df=3
# likelihood ratio test: chi2=1.7067  , p=0.6354  , df=3
# parameter F test:         F=0.5459  , p=0.6517  , df_denom=146, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5226  , p=0.7193  , df_denom=143, df_num=4
# ssr based chi2 test:   chi2=2.2219  , p=0.6950  , df=4
# likelihood ratio test: chi2=2.2058  , p=0.6980  , df=4
# parameter F test:         F=0.5226  , p=0.7193  , df_denom=143, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4143  , p=0.8382  , df_denom=140, df_num=5
# ssr based chi2 test:   chi2=2.2343  , p=0.8159  , df=5
# likelihood ratio test: chi2=2.2179  , p=0.8182  , df=5
# parameter F test:         F=0.4143  , p=0.8382  , df_denom=140, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.2369  , p=0.9637  , df_denom=137, df_num=6
# ssr based chi2 test:   chi2=1.5560  , p=0.9557  , df=6
# likelihood ratio test: chi2=1.5479  , p=0.9562  , df=6
# parameter F test:         F=0.2369  , p=0.9637  , df_denom=137, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.2970  , p=0.9540  , df_denom=134, df_num=7
# ssr based chi2 test:   chi2=2.3119  , p=0.9406  , df=7
# likelihood ratio test: chi2=2.2942  , p=0.9418  , df=7
# parameter F test:         F=0.2970  , p=0.9540  , df_denom=134, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.2794  , p=0.9717  , df_denom=131, df_num=8
# ssr based chi2 test:   chi2=2.5250  , p=0.9606  , df=8
# likelihood ratio test: chi2=2.5037  , p=0.9616  , df=8
# parameter F test:         F=0.2794  , p=0.9717  , df_denom=131, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3489  , p=0.9565  , df_denom=128, df_num=9
# ssr based chi2 test:   chi2=3.6058  , p=0.9354  , df=9
# likelihood ratio test: chi2=3.5623  , p=0.9378  , df=9
# parameter F test:         F=0.3489  , p=0.9565  , df_denom=128, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5360  , p=0.8618  , df_denom=125, df_num=10
# ssr based chi2 test:   chi2=6.2604  , p=0.7929  , df=10
# likelihood ratio test: chi2=6.1299  , p=0.8042  , df=10
# parameter F test:         F=0.5360  , p=0.8618  , df_denom=125, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.8964  , p=0.5461  , df_denom=122, df_num=11
# ssr based chi2 test:   chi2=11.7191 , p=0.3851  , df=11
# likelihood ratio test: chi2=11.2696 , p=0.4210  , df=11
# parameter F test:         F=0.8964  , p=0.5461  , df_denom=122, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.8878  , p=0.5613  , df_denom=119, df_num=12
# ssr based chi2 test:   chi2=12.8923 , p=0.3769  , df=12
# likelihood ratio test: chi2=12.3475 , p=0.4182  , df=12
# parameter F test:         F=0.8878  , p=0.5613  , df_denom=119, df_num=12

# %%
t = grangercausalitytests(pd.DataFrame({'volume': sigma}).join(betas[['GSCI-MSCI_W-smth']]).dropna(), maxlag=12)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3648  , p=0.2445  , df_denom=153, df_num=1
# ssr based chi2 test:   chi2=1.3916  , p=0.2381  , df=1
# likelihood ratio test: chi2=1.3854  , p=0.2392  , df=1
# parameter F test:         F=1.3648  , p=0.2445  , df_denom=153, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4883  , p=0.6146  , df_denom=150, df_num=2
# ssr based chi2 test:   chi2=1.0092  , p=0.6037  , df=2
# likelihood ratio test: chi2=1.0060  , p=0.6047  , df=2
# parameter F test:         F=0.4883  , p=0.6146  , df_denom=150, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3328  , p=0.8016  , df_denom=147, df_num=3
# ssr based chi2 test:   chi2=1.0459  , p=0.7901  , df=3
# likelihood ratio test: chi2=1.0424  , p=0.7910  , df=3
# parameter F test:         F=0.3328  , p=0.8016  , df_denom=147, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4467  , p=0.7746  , df_denom=144, df_num=4
# ssr based chi2 test:   chi2=1.8985  , p=0.7544  , df=4
# likelihood ratio test: chi2=1.8869  , p=0.7566  , df=4
# parameter F test:         F=0.4467  , p=0.7746  , df_denom=144, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4244  , p=0.8311  , df_denom=141, df_num=5
# ssr based chi2 test:   chi2=2.2877  , p=0.8081  , df=5
# likelihood ratio test: chi2=2.2707  , p=0.8106  , df=5
# parameter F test:         F=0.4244  , p=0.8311  , df_denom=141, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3998  , p=0.8781  , df_denom=138, df_num=6
# ssr based chi2 test:   chi2=2.6248  , p=0.8542  , df=6
# likelihood ratio test: chi2=2.6023  , p=0.8568  , df=6
# parameter F test:         F=0.3998  , p=0.8781  , df_denom=138, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5610  , p=0.7864  , df_denom=135, df_num=7
# ssr based chi2 test:   chi2=4.3633  , p=0.7371  , df=7
# likelihood ratio test: chi2=4.3010  , p=0.7445  , df=7
# parameter F test:         F=0.5610  , p=0.7864  , df_denom=135, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5300  , p=0.8322  , df_denom=132, df_num=8
# ssr based chi2 test:   chi2=4.7863  , p=0.7802  , df=8
# likelihood ratio test: chi2=4.7110  , p=0.7880  , df=8
# parameter F test:         F=0.5300  , p=0.8322  , df_denom=132, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4838  , p=0.8834  , df_denom=129, df_num=9
# ssr based chi2 test:   chi2=4.9951  , p=0.8347  , df=9
# likelihood ratio test: chi2=4.9126  , p=0.8419  , df=9
# parameter F test:         F=0.4838  , p=0.8834  , df_denom=129, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7053  , p=0.7181  , df_denom=126, df_num=10
# ssr based chi2 test:   chi2=8.2283  , p=0.6065  , df=10
# likelihood ratio test: chi2=8.0063  , p=0.6282  , df=10
# parameter F test:         F=0.7053  , p=0.7181  , df_denom=126, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.6971  , p=0.7393  , df_denom=123, df_num=11
# ssr based chi2 test:   chi2=9.1014  , p=0.6125  , df=11
# likelihood ratio test: chi2=8.8289  , p=0.6377  , df=11
# parameter F test:         F=0.6971  , p=0.7393  , df_denom=123, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.6665  , p=0.7804  , df_denom=120, df_num=12
# ssr based chi2 test:   chi2=9.6638  , p=0.6454  , df=12
# likelihood ratio test: chi2=9.3554  , p=0.6723  , df=12
# parameter F test:         F=0.6665  , p=0.7804  , df_denom=120, df_num=12
